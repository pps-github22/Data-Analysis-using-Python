# %% [markdown]
# Dataset: Popular Baby Names | Popularly used Pandas function

# %% [markdown]
# In this example, the pd.read_csv function reads the file ‘data.csv’ and converts it into a DataFrame, which is then assigned to the variable ‘data’. The contents of the DataFrame can then be printed using the print function.
#
# It has many options like sep, header, index_col, skiprows, na_values etc.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Popular_Baby_Names.csv')

# %%
df.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %% [markdown]
# df.describe()
# The df.describe() method in pandas is used to generate summary statistics of various features of a DataFrame. It returns a new DataFrame that contains the count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum of each numerical column in the original DataFrame.

# %%
import numpy as np

# %%
df.describe()
# Out:
#        Year of Birth         Count          Rank
# count   49509.000000  49509.000000  49509.000000
# mean     2013.407421     33.839807     57.032418
# std         2.145505     38.877785     25.504754
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2013.000000     20.000000     58.000000
# 75%      2014.000000     36.000000     78.000000
# max      2019.000000    426.000000    102.000000

# %%
# can also include and exclude certain columns
df.describe(include = 'all')
# Out:
#         Year of Birth  Gender  ...         Count          Rank
# count    49509.000000   49509  ...  49509.000000  49509.000000
# unique            NaN       2  ...           NaN           NaN
# top               NaN  FEMALE  ...           NaN           NaN
# freq              NaN   25275  ...           NaN           NaN
# mean      2013.407421     NaN  ...     33.839807     57.032418
# std          2.145505     NaN  ...     38.877785     25.504754
# min       2011.000000     NaN  ...     10.000000      1.000000
# 25%       2012.000000     NaN  ...     13.000000     38.000000
# 50%       2013.000000     NaN  ...     20.000000     58.000000
# 75%       2014.000000     NaN  ...     36.000000     78.000000
# max       2019.000000     NaN  ...    426.000000    102.000000
#
# [11 rows x 6 columns]

# %%
#exclude numerical columns
df.describe(exclude = 'number')
# Out:
#         Gender Ethnicity Child's First Name
# count    49509     49509              49509
# unique       2         7               3211
# top     FEMALE  HISPANIC              Avery
# freq     25275     14530                100

# %% [markdown]
# df.info():
# concise summary of a dataframe, including null values, data types and the memory usage of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49509 entries, 0 to 49508
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year of Birth       49509 non-null  int64
#  1   Gender              49509 non-null  object
#  2   Ethnicity           49509 non-null  object
#  3   Child's First Name  49509 non-null  object
#  4   Count               49509 non-null  int64
#  5   Rank                49509 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# df.plot():
# used to create various types of plots in dataframe
# by default, it creates a line plotof all numerical columns
# can also pass argument kind to specify the type of plot you want to create.
# Avaiable options: line, bar, barh, hist, box, kde, density, area, pie, scatter, and hexbin
#
# df.plot() is a convenient wrapper around the matplotlib.pyplot library

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['Gender'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Gender'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='Gender'>

# %%
df['Gender'].value_counts().plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# It also supports many other options like title, xlabel, ylabel, legand, grid, xlim, xticks etc.

# %% [markdown]
# df.iloc():
# used to select rows and columns by their integer-based index in dataframe.
#
# used to select rows and columns by their integer-based location.

# %%
df.iloc()

# %%
df.iloc[0]
# Out:
# Year of Birth              2011
# Gender                   FEMALE
# Ethnicity              HISPANIC
# Child's First Name    GERALDINE
# Count                        13
# Rank                         75
# Name: 0, dtype: object

# %%
# select the 1st 2 rows

df.iloc[:2]
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67

# %%
# select the 1st column

df.iloc[:, 0]
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 49504    2018
# 49505    2018
# 49506    2018
# 49507    2018
# 49508    2018
# Name: Year of Birth, Length: 49509, dtype: int64

# %%
# select the (1,1) element

df.iloc[1,1]
# Out:
# 'FEMALE'

# %% [markdown]
# df.loc():
# used to select rows and columns by thier label-based index in a dataframe
# select by their label-based location

# %%
# select the column named Gender

df.loc[:, 'Gender']
# Out:
# 0        FEMALE
# 1        FEMALE
# 2        FEMALE
# 3        FEMALE
# 4        FEMALE
#           ...
# 49504    FEMALE
# 49505    FEMALE
# 49506    FEMALE
# 49507    FEMALE
# 49508    FEMALE
# Name: Gender, Length: 49509, dtype: object

# %%
# select the column named Gender and Year of Birth

df.loc[:, ['Year of Birth', 'Gender']]
# Out:
#        Year of Birth  Gender
# 0               2011  FEMALE
# 1               2011  FEMALE
# 2               2011  FEMALE
# 3               2011  FEMALE
# 4               2011  FEMALE
# ...              ...     ...
# 49504           2018  FEMALE
# 49505           2018  FEMALE
# 49506           2018  FEMALE
# 49507           2018  FEMALE
# 49508           2018  FEMALE
#
# [49509 rows x 2 columns]

# %% [markdown]
# df.assign():
# used to add new columns to a dataframe, based on the computation of exisisting columns
#
# allows you to add new columns a DataFrame without modifying the original dataframe. The function returns a new DataFrame with the added columns.

# %%
# the first time df.assign() is used to create a new column named 'count_plus_5' with the value of count + 5.

df_new = df.assign(count_plus_5=df['Count'] + 5)
df_new.head()
# Out:
#    Year of Birth  Gender Ethnicity  ... Count  Rank  count_plus_5
# 0           2011  FEMALE  HISPANIC  ...    13    75            18
# 1           2011  FEMALE  HISPANIC  ...    21    67            26
# 2           2011  FEMALE  HISPANIC  ...    49    42            54
# 3           2011  FEMALE  HISPANIC  ...    38    51            43
# 4           2011  FEMALE  HISPANIC  ...    36    53            41
#
# [5 rows x 7 columns]

# %% [markdown]
# .query():
# function allows you to filter a DataFrame based on a Boolean expression.
#
# It allows you to select rows from a DataFrame using a query string similar to SQL.
#
# The function returns a new DataFrame containing only the rows that satisfy the Boolean expression.

# %%
# Select rows where age is greater than 30 and income is less than 65000

df_query = df.query('Count > 30 and Rank < 20')
df_query.head()
# Out:
#      Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 6             2011  FEMALE  HISPANIC             HAILEY    126     8
# 22            2011  FEMALE  HISPANIC           ISABELLA    331     1
# 81            2011  FEMALE  HISPANIC           KIMBERLY    103    13
# 90            2011  FEMALE  HISPANIC               LEAH    123     9
# 109           2011  FEMALE  HISPANIC            MADISON    122    10

# %% [markdown]
# df.query() is used to select rows where the count is greater than 30 and the rank is less than 30, and the second time df.query() is used to select rows where gender is 'MALE'.

# %%
# Select rows where gender is Male


df_query = df.query("Gender == 'MALE'")
df_query.head()
# Out:
#      Year of Birth Gender  ... Count Rank
# 363           2013   MALE  ...    25   80
# 416           2013   MALE  ...    25   80
# 547           2011   MALE  ...    15   51
# 548           2011   MALE  ...    51   19
# 549           2011   MALE  ...    20   46
#
# [5 rows x 6 columns]

# %% [markdown]
# .query() method can be used with any valid Boolean expression and it's useful when you want to filter a DataFrame based on multiple conditions or when the conditions are complex and hard to express using the standard indexing operators.
#
# Also, keep in mind that the .query() method is slower than boolean indexing, so if performance is critical, you should use boolean indexing instead.

# %% [markdown]
# .sort_values():
#
#  function allows you to sort a DataFrame by one or multiple columns. It sorts the DataFrame based on the values of one or more columns, in ascending or descending order. The function returns a new DataFrame sorted by the specified column(s).

# %%
# Sort by age in ascending order

df_sorted = df.sort_values(by='Count')
df_sorted.head()
# Out:
#        Year of Birth  Gender  ... Count Rank
# 49508           2018  FEMALE  ...    10   40
# 25037           2017    MALE  ...    10   89
# 25038           2017    MALE  ...    10   89
# 25039           2017    MALE  ...    10   89
# 25040           2017    MALE  ...    10   89
#
# [5 rows x 6 columns]

# %%
# Sort by income in descending order

df_sorted = df.sort_values(by='Rank', ascending=False)
df_sorted.head()
# Out:
#        Year of Birth Gender           Ethnicity Child's First Name  Count  Rank
# 23260           2014   MALE  WHITE NON HISPANIC           Giuseppe     10   102
# 12827           2014   MALE  WHITE NON HISPANIC              Denis     10   102
# 47427           2014   MALE  WHITE NON HISPANIC              Karas     10   102
# 23281           2014   MALE  WHITE NON HISPANIC              Imran     10   102
# 8188            2014   MALE  WHITE NON HISPANIC           Giuseppe     10   102

# %%
# Sort by multiple columns

df_sorted = df.sort_values(by=['Count', 'Rank'])
df_sorted.head()
# Out:
#        Year of Birth  Gender  ... Count Rank
# 39473           2019  FEMALE  ...    10   34
# 39474           2019  FEMALE  ...    10   34
# 39475           2019  FEMALE  ...    10   34
# 39476           2019  FEMALE  ...    10   34
# 39477           2019  FEMALE  ...    10   34
#
# [5 rows x 6 columns]

# %% [markdown]
# .sample():
#
# function allows you to randomly select rows from a DataFrame. It returns a new DataFrame containing the randomly selected rows. The function takes several parameters that allow you to control the sampling process, such as the number of rows to return, and whether or not to sample with replacement and seed for reproducibility.

# %%
# Sample 2 rows without replacement

df_sample = df.sample(n=2, replace=False, random_state=1)
df_sample
# Out:
#        Year of Birth  Gender  ... Count Rank
# 19106           2013  FEMALE  ...    12   45
# 46016           2014  FEMALE  ...    32   51
#
# [2 rows x 6 columns]

# %%
# Sample 3 rows with replacement

df_sample = df.sample(n=3, replace=True, random_state=1)
df_sample
# Out:
#        Year of Birth  Gender  ... Count Rank
# 33003           2015  FEMALE  ...    10   40
# 12172           2014    MALE  ...    12   56
# 5192            2012    MALE  ...    32   39
#
# [3 rows x 6 columns]

# %%
# Sample 2 rows without replacement with specific column to be chosen

df_sample = df.sample(n=2, replace=False, random_state=1, axis=1)
df_sample
# Out:
#                 Ethnicity  Gender
# 0                HISPANIC  FEMALE
# 1                HISPANIC  FEMALE
# 2                HISPANIC  FEMALE
# 3                HISPANIC  FEMALE
# 4                HISPANIC  FEMALE
# ...                   ...     ...
# 49504  BLACK NON HISPANIC  FEMALE
# 49505  BLACK NON HISPANIC  FEMALE
# 49506  BLACK NON HISPANIC  FEMALE
# 49507  BLACK NON HISPANIC  FEMALE
# 49508  BLACK NON HISPANIC  FEMALE
#
# [49509 rows x 2 columns]

# %% [markdown]
# isnull():
#
# method in Pandas returns a DataFrame of the same shape as the original DataFrame, but with True or False values indicating whether each value in the original DataFrame is missing or not. Missing values, such as NaN or None, will be True in the resulting DataFrame, while non-missing values will be False.

# %%
df.isnull()
# Out:
#        Year of Birth  Gender  Ethnicity  Child's First Name  Count   Rank
# 0              False   False      False               False  False  False
# 1              False   False      False               False  False  False
# 2              False   False      False               False  False  False
# 3              False   False      False               False  False  False
# 4              False   False      False               False  False  False
# ...              ...     ...        ...                 ...    ...    ...
# 49504          False   False      False               False  False  False
# 49505          False   False      False               False  False  False
# 49506          False   False      False               False  False  False
# 49507          False   False      False               False  False  False
# 49508          False   False      False               False  False  False
#
# [49509 rows x 6 columns]

# %% [markdown]
# fillna():
# method in Pandas is used to fill in missing values in a DataFrame with a specified value or method. By default, it replaces missing values with NaN, but you can specify a different value to use instead as shown below:

# %% [markdown]
# value: Specifies the value to use to fill in the missing values. Can be a scalar value or a dict of values for different columns.
#
# method: Specifies the method to use for filling in missing values. Can be 'ffill' (forward-fill) or 'bfill' (backward-fill) or 'interpolate'(interpolate values) or 'pad' or 'backfill'
#
# axis: Specifies the axis along which to fill in missing values. It can be 0 (rows) or 1 (columns).
#
# inplace: Whether to fill in the missing values in place (modifying the original DataFrame) or to return a new DataFrame with the missing values filled in.
#
# limit: Specifies the maximum number of consecutive missing values to fill.
#
# downcast: Specifies a dictionary of values to use to downcast the data types of columns.

# %%
# fill missing values with 0
df.fillna(0)
# Out:
#        Year of Birth  Gender  ... Count Rank
# 0               2011  FEMALE  ...    13   75
# 1               2011  FEMALE  ...    21   67
# 2               2011  FEMALE  ...    49   42
# 3               2011  FEMALE  ...    38   51
# 4               2011  FEMALE  ...    36   53
# ...              ...     ...  ...   ...  ...
# 49504           2018  FEMALE  ...    10   40
# 49505           2018  FEMALE  ...    10   40
# 49506           2018  FEMALE  ...    10   40
# 49507           2018  FEMALE  ...    10   40
# 49508           2018  FEMALE  ...    10   40
#
# [49509 rows x 6 columns]

# %%
# forward-fill missing values (propagates last valid observation forward to next)
df.fillna(method='ffill')
# Out:
#        Year of Birth  Gender  ... Count Rank
# 0               2011  FEMALE  ...    13   75
# 1               2011  FEMALE  ...    21   67
# 2               2011  FEMALE  ...    49   42
# 3               2011  FEMALE  ...    38   51
# 4               2011  FEMALE  ...    36   53
# ...              ...     ...  ...   ...  ...
# 49504           2018  FEMALE  ...    10   40
# 49505           2018  FEMALE  ...    10   40
# 49506           2018  FEMALE  ...    10   40
# 49507           2018  FEMALE  ...    10   40
# 49508           2018  FEMALE  ...    10   40
#
# [49509 rows x 6 columns]

# %%
# backward-fill missing values (propagates next valid observation backward to last)
df.fillna(method='bfill')
# Out:
#        Year of Birth  Gender  ... Count Rank
# 0               2011  FEMALE  ...    13   75
# 1               2011  FEMALE  ...    21   67
# 2               2011  FEMALE  ...    49   42
# 3               2011  FEMALE  ...    38   51
# 4               2011  FEMALE  ...    36   53
# ...              ...     ...  ...   ...  ...
# 49504           2018  FEMALE  ...    10   40
# 49505           2018  FEMALE  ...    10   40
# 49506           2018  FEMALE  ...    10   40
# 49507           2018  FEMALE  ...    10   40
# 49508           2018  FEMALE  ...    10   40
#
# [49509 rows x 6 columns]

# %%
# fill missing values using interpolation
df.interpolate()
# Out:
#        Year of Birth  Gender  ... Count Rank
# 0               2011  FEMALE  ...    13   75
# 1               2011  FEMALE  ...    21   67
# 2               2011  FEMALE  ...    49   42
# 3               2011  FEMALE  ...    38   51
# 4               2011  FEMALE  ...    36   53
# ...              ...     ...  ...   ...  ...
# 49504           2018  FEMALE  ...    10   40
# 49505           2018  FEMALE  ...    10   40
# 49506           2018  FEMALE  ...    10   40
# 49507           2018  FEMALE  ...    10   40
# 49508           2018  FEMALE  ...    10   40
#
# [49509 rows x 6 columns]

# %% [markdown]
# Note that:
#
# the fillna() method returns a new DataFrame with the missing values filled in and does not modify the original DataFrame in place. If you want to modify the original DataFrame, you can use the inplace parameter and set it to True.

# %%
# fill missing values in place

df.fillna(0, inplace=True)

# %% [markdown]
# df.dropna():
# used in the Pandas library to remove missing or null values from a DataFrame. It removes rows or columns from the DataFrame where at least one element is missing.
#
# You can remove all rows containing at least one missing value by calling df.dropna().

# %%
df = df.dropna()

# %% [markdown]
# If you want to remove only the columns that contain at least one missing value you can use df.dropna(axis=1)

# %%
df = df.dropna(axis=1)

# %% [markdown]
# You can also set thresh parameter to keep only the rows/columns that have at least thresh non-NA/null values.

# %%
df = df.dropna(thresh=2)

# %% [markdown]
# df.drop():
#
# is a method used in the Pandas library to remove rows or columns from a DataFrame by specifying the corresponding labels. It can be used to drop one or multiple rows or columns based on their labels.

# %% [markdown]
# You can remove a specific row by calling df.drop() and passing the index label of the row you want to remove, and the axis parameter set to 0 (default is 0)

# %%
# This would remove the first row of the DataFrame.

df_drop = df.drop(0)

# %% [markdown]
# You can also drop multiple rows by passing a list of index labels

# %%
#This would remove the first and second rows of the DataFrame.

df_drop = df.drop([0,1])

# %%
df_drop = df.drop(['Count', 'Rank'], axis=1)

# %% [markdown]
# pd.pivot_table():
#
# is a method in the Pandas library that is used to create a pivot table from a DataFrame. A pivot table is a table that summarizes and aggregates data in a more meaningful and organized way, by creating a new table with one or more columns as the index, one or more columns as values, and one or more columns as attributes.

# %% [markdown]
# In the example below we will create a pivot table with Ethnicity as the index and aggregate the sum of the count. This is used to know the count of each Ethnicity in the dataset.

# %%
pivot_table = pd.pivot_table(df, index='Ethnicity', values='Count', aggfunc='sum')
pivot_table.head()
# Out:
#                              Count
# Ethnicity
# ASIAN AND PACI               50385
# ASIAN AND PACIFIC ISLANDER  175258
# BLACK NON HISP               49634
# BLACK NON HISPANIC          192286
# HISPANIC                    557388

# %% [markdown]
# You can also include more columns in the pivot table by specifying multiple index and values parameters and also include multiple aggfunc functions.

# %%
pivot_table = pd.pivot_table(df, index=['Ethnicity','Gender'], values= 'Count' , aggfunc=['sum','count'])
pivot_table.head(20)
# Out:
#                                       sum count
#                                     Count Count
# Ethnicity                  Gender
# ASIAN AND PACI             FEMALE   21424   887
#                            MALE     28961   880
# ASIAN AND PACIFIC ISLANDER FEMALE   75184  3380
#                            MALE    100074  3419
# BLACK NON HISP             FEMALE   20665   843
#                            MALE     28969   897
# BLACK NON HISPANIC         FEMALE   81268  3566
#                            MALE    111018  3647
# HISPANIC                   FEMALE  235634  7443
#                            MALE    321754  7087
# WHITE NON HISP             FEMALE   60562  1825
#                            MALE     69942  1616
# WHITE NON HISPANIC         FEMALE  240384  7331
#                            MALE    279536  6688

# %% [markdown]
# df.groupby():
#
# is a method in the Pandas library that is used to group rows of a DataFrame based on one or multiple columns. This allows you to perform aggregate operations on the groups, such as calculating the mean, sum, or count of the values in each group.

# %% [markdown]
# df.groupby() returns a GroupBy object, which you can then use to perform various operations on the groups, such as calculating the sum, mean, or count of the values in each group.

# %%
grouped = df.groupby('Gender')
# Print the mean of each group
print(grouped.mean())
# Out:
#         Year of Birth      Count       Rank
# Gender
# FEMALE    2013.399169  29.084906  51.955252
# MALE      2013.416027  38.798960  62.327680
# C:\Users\mohap\AppData\Local\Temp\ipykernel_17124\567807611.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(grouped.mean())

# %%
grouped = df.groupby(['Gender', 'Ethnicity'])

# Print the sum of each group
print(grouped.sum())
# Out:
#                                    Year of Birth   Count    Rank
# Gender Ethnicity
# FEMALE ASIAN AND PACI                    1784644   21424   29649
#        ASIAN AND PACIFIC ISLANDER        6806626   75184  101302
#        BLACK NON HISP                    1696116   20665   28740
#        BLACK NON HISPANIC                7180868   81268  112432
#        HISPANIC                         14984994  235634  441797
#        WHITE NON HISP                    3671900   60562  119034
#        WHITE NON HISPANIC               14763516  240384  480215
# MALE   ASIAN AND PACI                    1770560   28961   38767
#        ASIAN AND PACIFIC ISLANDER        6885430  100074  141247
#        BLACK NON HISP                    1804764   28969   39236
#        BLACK NON HISPANIC                7343726  111018  162999
#        HISPANIC                         14268608  321754  507232
#        WHITE NON HISP                    3251392   69942  114072
#        WHITE NON HISPANIC               13468644  279536  506896
# C:\Users\mohap\AppData\Local\Temp\ipykernel_17124\2700189207.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(grouped.sum())

# %% [markdown]
# df.transpose():
#
#  is a method in the Pandas library used to transpose the rows and columns of a DataFrame? This means that the rows become columns and the columns become rows.

# %%
# Transpose the DataFrame
df_transposed = df.transpose()

# Print the transposed DataFrame
df_transposed.head()
# Out:
#                         0         1      ...               49507               49508
# Year of Birth            2011      2011  ...                2018                2018
# Gender                 FEMALE    FEMALE  ...              FEMALE              FEMALE
# Ethnicity            HISPANIC  HISPANIC  ...  BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name  GERALDINE       GIA  ...              Simone               Zahra
# Count                      13        21  ...                  10                  10
#
# [5 rows x 49509 columns]

# %% [markdown]
# It can also be done using T attributes on the dataframe. df.T will do the same as df.transpose().

# %%
df_transposed = df.T
df_transposed.head()
# Out:
#                         0         1      ...               49507               49508
# Year of Birth            2011      2011  ...                2018                2018
# Gender                 FEMALE    FEMALE  ...              FEMALE              FEMALE
# Ethnicity            HISPANIC  HISPANIC  ...  BLACK NON HISPANIC  BLACK NON HISPANIC
# Child's First Name  GERALDINE       GIA  ...              Simone               Zahra
# Count                      13        21  ...                  10                  10
#
# [5 rows x 49509 columns]

# %% [markdown]
# df.merge():
#
# is a pandas function that allows you to combine two DataFrames based on one or more common columns. It is similar to SQL JOINs. The function returns a new DataFrame that contains only the rows where the values in the specified columns match between the two DataFrames.

# %%
# Create the first DataFrame
df1 = pd.DataFrame({'key': ['A', 'B', 'C', 'D'],
                   'value': [1, 2, 3, 4]})

# Create the second DataFrame
df2 = pd.DataFrame({'key': ['B', 'D', 'E', 'F'],
                   'value': [5, 6, 7, 8]})

# Merge the two DataFrames on the 'key' column
merged_df = df1.merge(df2, on='key')

# Print the merged DataFrame
print(merged_df)
# Out:
#   key  value_x  value_y
# 0   B        2        5
# 1   D        4        6

# %%
#You can also merge multiple columns by passing a list of columns to the on parameter.

merged_df = df1.merge(df2, on=['key1','key2'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 3
#       1 #You can also merge multiple columns by passing a list of columns to the on parameter.
# ----> 3 merged_df = df1.merge(df2, on=['key1','key2'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
#   10086     validate: str | None = None,
#   10087 ) -> DataFrame:
#   10088     from pandas.core.reshape.merge import merge
# > 10090     return merge(
#   10091         self,
#   10092         right,
#   10093         how=how,
#   10094         on=on,
#   10095         left_on=left_on,
#   10096         right_on=right_on,
#   10097         left_index=left_index,
#   10098         right_index=right_index,
#   10099         sort=sort,
#   10100         suffixes=suffixes,
#   10101         copy=copy,
#   10102         indicator=indicator,
#   10103         validate=validate,
#   10104     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'key1'

# %%
#You can also specify a different column name to merge by using left_on and right_on parameters.

merged_df = df1.merge(df2, left_on='key1', right_on='key3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 3
#       1 #You can also specify a different column name to merge by using left_on and right_on parameters.
# ----> 3 merged_df = df1.merge(df2, left_on='key1', right_on='key3')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:10090, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10071 @Substitution("")
#   10072 @Appender(_merge_doc, indents=2)
#   10073 def merge(
#    (...)
#   10086     validate: str | None = None,
#   10087 ) -> DataFrame:
#   10088     from pandas.core.reshape.merge import merge
# > 10090     return merge(
#   10091         self,
#   10092         right,
#   10093         how=how,
#   10094         on=on,
#   10095         left_on=left_on,
#   10096         right_on=right_on,
#   10097         left_index=left_index,
#   10098         right_index=right_index,
#   10099         sort=sort,
#   10100         suffixes=suffixes,
#   10101         copy=copy,
#   10102         indicator=indicator,
#   10103         validate=validate,
#   10104     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:1162, in _MergeOperation._get_merge_keys(self)
#    1160 rk = cast(Hashable, rk)
#    1161 if rk is not None:
# -> 1162     right_keys.append(right._get_label_or_level_values(rk))
#    1163 else:
#    1164     # work-around for merge_asof(right_index=True)
#    1165     right_keys.append(right.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'key3'

# %% [markdown]
# df.rename():
#
#  is a pandas function that allows you to change the name of one or more columns or rows in a DataFrame. You can use the columns parameter to change the column names, and the index parameter to change the row names.

# %%
# Rename column 'Count' to 'count'
df_rename = df.rename(columns={'Count': 'count'})
df_rename.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
#You can also use a dictionary to rename multiple columns at once:

df_rename = df.rename(columns={'Count': 'count', 'Rank':'rank'})
df_rename.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  count  rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
#can also rename the index similarly:

df_rename = df.rename(index={0:'first',1:'second',2:'third'})
df_rename.head()
# Out:
#         Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# first            2011  FEMALE  HISPANIC          GERALDINE     13    75
# second           2011  FEMALE  HISPANIC                GIA     21    67
# third            2011  FEMALE  HISPANIC             GIANNA     49    42
# 3                2011  FEMALE  HISPANIC            GISELLE     38    51
# 4                2011  FEMALE  HISPANIC              GRACE     36    53

# %% [markdown]
# df.to_csv():
#
# is a method used in the Pandas library to export a DataFrame to a CSV file. CSV stands for "Comma Separated Values" and it is a popular file format for storing data in a tabular form.

# %%
#This will save the DataFrame to a file named data.csv in the current working directory. 

df.to_csv('data.csv')

# %%
#can also use the index parameter to specify whether to include or exclude the index of the dataframe in the exported CSV file.

df.to_csv('path/to/data.csv', index=False)

# %%
df_new = pd.read_csv('data.csv')
df_new.head()
# Out:
#    Unnamed: 0  Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           4           2011  FEMALE  HISPANIC              GRACE     36    53
