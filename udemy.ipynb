# %% [markdown]
# Analysis on Udemy Courses

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Getting the structure and type of the data from the datafiles

# %%
df = pd.read_csv('udemy_courses.csv')
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df.sample()
# Out:
#       course_id                                       course_title  \
# 3020    1064104  Laravel, the complete guide with real world pr...
#
#                                       url  is_paid  price  num_subscribers  \
# 3020  https://www.udemy.com/best-laravel/     True    200              676
#
#       num_reviews  num_lectures       level  content_duration  \
# 3020          119           125  All Levels              14.0
#
#        published_timestamp          subject
# 3020  2017-02-03T16:28:48Z  Web Development

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %% [markdown]
# Data Cleaning
#
# Null values are represented by None or NAN (not a number) in Pandas.

# %%
# isna(): denotes whether null values are present in an object or not. 

df.isna().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# There is no issing value in our dataframe then.

# %%
#dropna(): removes the rows that contains NULL values.
#inplace = true will modify the df you are currently working on

df.dropna(inplace=True)
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df[df.duplicated()]
# Out:
#       course_id                                       course_title  \
# 787      837322  Essentials of money value: Get a financial Life !
# 788     1157298  Introduction to Forex Trading Business For Beg...
# 894     1035638                 Understanding Financial Statements
# 1100    1084454                  CFA Level 2- Quantitative Methods
# 1473     185526                             MicroStation - Células
# 2561      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
#
#                                                     url  is_paid  price  \
# 787    https://www.udemy.com/essentials-of-money-value/     True     20
# 788   https://www.udemy.com/introduction-to-forex-tr...     True     20
# 894   https://www.udemy.com/understanding-financial-...     True     25
# 1100  https://www.udemy.com/cfa-level-2-quantitative...     True     40
# 1473        https://www.udemy.com/microstation-celulas/     True     20
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Length: 3678, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop('url',axis=1,inplace=True)
df
# Out:
#       course_id                                       course_title  is_paid  \
# 0       1070968                 Ultimate Investment Banking Course     True
# 1       1113822  Complete GST Course & Certification - Grow You...     True
# 2       1006314  Financial Modeling for Business Analysts and C...     True
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4       1011058       How To Maximize Your Profits Trading Options     True
# ...         ...                                                ...      ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...     True
# 3674    1088178  How To Design A WordPress Website With No Codi...     True
# 3675     635248                      Learn and Build using Polymer     True
# 3676     905096  CSS Animations: Create Amazing Effects on Your...     True
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...     True
#
# ...

# %%
df.head()

# see the current dataframe
# Out:
#    course_id                                       course_title  is_paid  \
# 0    1070968                 Ultimate Investment Banking Course     True
# 1    1113822  Complete GST Course & Certification - Grow You...     True
# 2    1006314  Financial Modeling for Business Analysts and C...     True
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4    1011058       How To Maximize Your Profits Trading Options     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0    200             2147           23            51          All Levels
# 1     75             2792          923           274          All Levels
# 2     45             2174           74            51  Intermediate Level
# 3     95             2451           11            36          All Levels
# 4    200             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# ...

# %% [markdown]
# Convert object datatype to date datatype
# convert data that on left and but it in the main column

# %%
df ['published_timestamp'] = pd.to_datetime(df ['published_timestamp']).dt.date

# %%
df.drop('course_id',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                         course_title  is_paid  price  \
# 0                 Ultimate Investment Banking Course     True    200
# 1  Complete GST Course & Certification - Grow You...     True     75
# 2  Financial Modeling for Business Analysts and C...     True     45
# 3  Beginner to Pro - Financial Analysis in Excel ...     True     95
# 4       How To Maximize Your Profits Trading Options     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration published_timestamp           subject
# 0               1.5          2017-01-18  Business Finance
# ...

# %% [markdown]
# Data Visualization:

# %% [markdown]
# 1. Categorical Data

# %%
plt.figure(figsize=(4,3))
sns.countplot(x='is_paid',data=df,palette="terrain_r")
plt.title('paid vs free courses')
# Out:
# Text(0.5, 1.0, 'paid vs free courses')

# %%
# count the number of free vs paid courses True means Paid and False means not paid

df['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
# %matplotlib inline

# count plot on single categorical variable
#sns.countplot(x ='sex', data = df)

plt.figure(figsize=(7,4))
sns.countplot(x = 'level',data=df,palette="terrain_r")
plt.title('Comparison between levels')
# Out:
# Text(0.5, 1.0, 'Comparison between levels')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x = 'subject',data=df,palette="terrain_r")
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
df['subject'].value_counts() #returns object containing counts of unique values
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %% [markdown]
# From here, we can see Web Developments has the highest number of value counts and 2nd is Business Finance

# %%
#corr=corrilation in math like relation if it was negative that mean Reverse
#if was possitive that mean Expel
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), linewidth=.5, cmap="crest", annot=True)
# Out:
# C:\Users\mohap\AppData\Local\Temp\ipykernel_18308\131276937.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), linewidth=.5, cmap="crest", annot=True)
# <Axes: >

# %% [markdown]
# Level Distribution of Udemy Courses

# %%
levels = ['All Levels','Beginner Level','Intermediate Level','Expert Level']
numbers = []
for i in df['subject'].unique():
    tempDF = df[df['subject']==i]
    for j in levels:
        numbers.append([i,j,len(tempDF[tempDF['level']==j])])
data = {
    'Subject':[i[0] for i in numbers],
    'Level':[i[1] for i in numbers],
    'Count':[i[2] for i in numbers]
}
splitDF = pd.DataFrame(numbers,columns=['Subject','Level','Count'])

# %%
colors = ["#eb8060", "#b9e38d", "#a1e9f0", "#d9b1f0"]

plt.figure(figsize=(16,8))
sns.barplot(data=splitDF,x='Subject',y='Count',hue='Level',palette=colors)
plt.title(label='Level distribution matched to each subject.')
plt.show()

# %% [markdown]
# Content Distribution on Udemy

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df['level'].value_counts().keys(),
            y=df['level'].value_counts(),palette=colors)
plt.title(label='Level of course distribution in dataset')
plt.show()

# %% [markdown]
# Udemy is best suited for which level of people

# %%
levels = ['All Levels','Beginner Level','Intermediate Level','Expert Level']
numbers = []
for i in df['subject'].unique():
    tempDF = df[df['subject']==i]
    for j in levels:
        numbers.append([i,j,len(tempDF[tempDF['level']==j])])
data = {
    'Subject':[i[0] for i in numbers],
    'Level':[i[1] for i in numbers],
    'Count':[i[2] for i in numbers]
}
splitDF = pd.DataFrame(numbers,columns=['Subject','Level','Count'])

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=splitDF,x='Subject',y='Count',hue='Level',palette=colors)
plt.title(label='Level distribution matched to each subject.')
plt.show()

# %% [markdown]
# But, from the below graph we can see most of the courses are paid courses in udemy

# %%
plt.figure(figsize=(16,8))
sns.histplot(data=df,x='is_paid',color='#eb8060')
plt.title(label='Free and paid course distribution in the dataset')
plt.show()
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
